# %%
from my_utils import BCI_analysis

# %%
BCI_analysis('BCICIV_calib_ds1a.mat')
# Out:
# some information
#
# Shape of EEG: (59, 190594)
# Sample rate: 100
# Number of channels: 59
# Channel names: ['AF3', 'AF4', 'F5', 'F3', 'F1', 'Fz', 'F2', 'F4', 'F6', 'FC5', 'FC3', 'FC1', 'FCz', 'FC2', 'FC4', 'FC6', 'CFC7', 'CFC5', 'CFC3', 'CFC1', 'CFC2', 'CFC4', 'CFC6', 'CFC8', 'T7', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'T8', 'CCP7', 'CCP5', 'CCP3', 'CCP1', 'CCP2', 'CCP4', 'CCP6', 'CCP8', 'CP5', 'CP3', 'CP1', 'CPz', 'CP2', 'CP4', 'CP6', 'P5', 'P3', 'P1', 'Pz', 'P2', 'P4', 'P6', 'PO1', 'PO2', 'O1', 'O2']
# Number of events: 1
# Event codes: [-1  1]
# Class labels: ['left', 'foot']
# Number of classes: 2
#
# trials shape
#
# Shape of trials[cl1]: (59, 200, 100)
# Shape of trials[cl2]: (59, 200, 100)
#
# Plots some PSD data
# Plotting the PSD of the resulting trials_filt
# Plot the log-vars
# Plot the log-vars after applying csp
# plots the PSD for the first and last components as well as one in the middle
# plot to see differentiate between the two classes
# ...

# %%
BCI_analysis('BCICIV_calib_ds1b.mat')
# Out:
# some information
#
# Shape of EEG: (59, 190594)
# Sample rate: 100
# Number of channels: 59
# Channel names: ['AF3', 'AF4', 'F5', 'F3', 'F1', 'Fz', 'F2', 'F4', 'F6', 'FC5', 'FC3', 'FC1', 'FCz', 'FC2', 'FC4', 'FC6', 'CFC7', 'CFC5', 'CFC3', 'CFC1', 'CFC2', 'CFC4', 'CFC6', 'CFC8', 'T7', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'T8', 'CCP7', 'CCP5', 'CCP3', 'CCP1', 'CCP2', 'CCP4', 'CCP6', 'CCP8', 'CP5', 'CP3', 'CP1', 'CPz', 'CP2', 'CP4', 'CP6', 'P5', 'P3', 'P1', 'Pz', 'P2', 'P4', 'P6', 'PO1', 'PO2', 'O1', 'O2']
# Number of events: 1
# Event codes: [-1  1]
# Class labels: ['left', 'right']
# Number of classes: 2
#
# trials shape
#
# Shape of trials[cl1]: (59, 200, 100)
# Shape of trials[cl2]: (59, 200, 100)
#
# Plots some PSD data
# Plotting the PSD of the resulting trials_filt
# Plot the log-vars
# Plot the log-vars after applying csp
# plots the PSD for the first and last components as well as one in the middle
# plot to see differentiate between the two classes
# ...

# %%
BCI_analysis('BCICIV_calib_ds1c.mat')
# Out:
# some information
#
# Shape of EEG: (59, 190549)
# Sample rate: 100
# Number of channels: 59
# Channel names: ['AF3', 'AF4', 'F5', 'F3', 'F1', 'Fz', 'F2', 'F4', 'F6', 'FC5', 'FC3', 'FC1', 'FCz', 'FC2', 'FC4', 'FC6', 'CFC7', 'CFC5', 'CFC3', 'CFC1', 'CFC2', 'CFC4', 'CFC6', 'CFC8', 'T7', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'T8', 'CCP7', 'CCP5', 'CCP3', 'CCP1', 'CCP2', 'CCP4', 'CCP6', 'CCP8', 'CP5', 'CP3', 'CP1', 'CPz', 'CP2', 'CP4', 'CP6', 'P5', 'P3', 'P1', 'Pz', 'P2', 'P4', 'P6', 'PO1', 'PO2', 'O1', 'O2']
# Number of events: 1
# Event codes: [-1  1]
# Class labels: ['left', 'right']
# Number of classes: 2
#
# trials shape
#
# Shape of trials[cl1]: (59, 200, 100)
# Shape of trials[cl2]: (59, 200, 100)
#
# Plots some PSD data
# Plotting the PSD of the resulting trials_filt
# Plot the log-vars
# Plot the log-vars after applying csp
# plots the PSD for the first and last components as well as one in the middle
# plot to see differentiate between the two classes
# ...

# %%
BCI_analysis('BCICIV_calib_ds1d.mat')
# Out:
# some information
#
# Shape of EEG: (59, 190473)
# Sample rate: 100
# Number of channels: 59
# Channel names: ['AF3', 'AF4', 'F5', 'F3', 'F1', 'Fz', 'F2', 'F4', 'F6', 'FC5', 'FC3', 'FC1', 'FCz', 'FC2', 'FC4', 'FC6', 'CFC7', 'CFC5', 'CFC3', 'CFC1', 'CFC2', 'CFC4', 'CFC6', 'CFC8', 'T7', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'T8', 'CCP7', 'CCP5', 'CCP3', 'CCP1', 'CCP2', 'CCP4', 'CCP6', 'CCP8', 'CP5', 'CP3', 'CP1', 'CPz', 'CP2', 'CP4', 'CP6', 'P5', 'P3', 'P1', 'Pz', 'P2', 'P4', 'P6', 'PO1', 'PO2', 'O1', 'O2']
# Number of events: 1
# Event codes: [-1  1]
# Class labels: ['left', 'right']
# Number of classes: 2
#
# trials shape
#
# Shape of trials[cl1]: (59, 200, 100)
# Shape of trials[cl2]: (59, 200, 100)
#
# Plots some PSD data
# Plotting the PSD of the resulting trials_filt
# Plot the log-vars
# Plot the log-vars after applying csp
# plots the PSD for the first and last components as well as one in the middle
# plot to see differentiate between the two classes
# ...

# %%
BCI_analysis('BCICIV_calib_ds1e.mat')
# Out:
# some information
#
# Shape of EEG: (59, 190329)
# Sample rate: 100
# Number of channels: 59
# Channel names: ['AF3', 'AF4', 'F5', 'F3', 'F1', 'Fz', 'F2', 'F4', 'F6', 'FC5', 'FC3', 'FC1', 'FCz', 'FC2', 'FC4', 'FC6', 'CFC7', 'CFC5', 'CFC3', 'CFC1', 'CFC2', 'CFC4', 'CFC6', 'CFC8', 'T7', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'T8', 'CCP7', 'CCP5', 'CCP3', 'CCP1', 'CCP2', 'CCP4', 'CCP6', 'CCP8', 'CP5', 'CP3', 'CP1', 'CPz', 'CP2', 'CP4', 'CP6', 'P5', 'P3', 'P1', 'Pz', 'P2', 'P4', 'P6', 'PO1', 'PO2', 'O1', 'O2']
# Number of events: 1
# Event codes: [-1  1]
# Class labels: ['left', 'right']
# Number of classes: 2
#
# trials shape
#
# Shape of trials[cl1]: (59, 200, 100)
# Shape of trials[cl2]: (59, 200, 100)
#
# Plots some PSD data
# Plotting the PSD of the resulting trials_filt
# Plot the log-vars
# Plot the log-vars after applying csp
# plots the PSD for the first and last components as well as one in the middle
# plot to see differentiate between the two classes
# ...

# %%
BCI_analysis('BCICIV_calib_ds1f.mat')
# Out:
# some information
#
# Shape of EEG: (59, 190608)
# Sample rate: 100
# Number of channels: 59
# Channel names: ['AF3', 'AF4', 'F5', 'F3', 'F1', 'Fz', 'F2', 'F4', 'F6', 'FC5', 'FC3', 'FC1', 'FCz', 'FC2', 'FC4', 'FC6', 'CFC7', 'CFC5', 'CFC3', 'CFC1', 'CFC2', 'CFC4', 'CFC6', 'CFC8', 'T7', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'T8', 'CCP7', 'CCP5', 'CCP3', 'CCP1', 'CCP2', 'CCP4', 'CCP6', 'CCP8', 'CP5', 'CP3', 'CP1', 'CPz', 'CP2', 'CP4', 'CP6', 'P5', 'P3', 'P1', 'Pz', 'P2', 'P4', 'P6', 'PO1', 'PO2', 'O1', 'O2']
# Number of events: 1
# Event codes: [-1  1]
# Class labels: ['left', 'foot']
# Number of classes: 2
#
# trials shape
#
# Shape of trials[cl1]: (59, 200, 100)
# Shape of trials[cl2]: (59, 200, 100)
#
# Plots some PSD data
# Plotting the PSD of the resulting trials_filt
# Plot the log-vars
# Plot the log-vars after applying csp
# plots the PSD for the first and last components as well as one in the middle
# plot to see differentiate between the two classes
# ...

# %%
BCI_analysis('BCICIV_calib_ds1g.mat')
# Out:
# some information
#
# Shape of EEG: (59, 190602)
# Sample rate: 100
# Number of channels: 59
# Channel names: ['AF3', 'AF4', 'F5', 'F3', 'F1', 'Fz', 'F2', 'F4', 'F6', 'FC5', 'FC3', 'FC1', 'FCz', 'FC2', 'FC4', 'FC6', 'CFC7', 'CFC5', 'CFC3', 'CFC1', 'CFC2', 'CFC4', 'CFC6', 'CFC8', 'T7', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'T8', 'CCP7', 'CCP5', 'CCP3', 'CCP1', 'CCP2', 'CCP4', 'CCP6', 'CCP8', 'CP5', 'CP3', 'CP1', 'CPz', 'CP2', 'CP4', 'CP6', 'P5', 'P3', 'P1', 'Pz', 'P2', 'P4', 'P6', 'PO1', 'PO2', 'O1', 'O2']
# Number of events: 1
# Event codes: [-1  1]
# Class labels: ['left', 'right']
# Number of classes: 2
#
# trials shape
#
# Shape of trials[cl1]: (59, 200, 100)
# Shape of trials[cl2]: (59, 200, 100)
#
# Plots some PSD data
# Plotting the PSD of the resulting trials_filt
# Plot the log-vars
# Plot the log-vars after applying csp
# plots the PSD for the first and last components as well as one in the middle
# plot to see differentiate between the two classes
# ...
